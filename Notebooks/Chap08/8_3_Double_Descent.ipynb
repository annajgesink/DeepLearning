# %% [markdown]
# <a href="https://colab.research.google.com/github/annajgesink/DeepLearning/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-jaczy5zr
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-jaczy5zr
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.11.12)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=a84699f665adc187f68f1add472c15f9d99c3033414ccad429931e522f683f0a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-naa60lgq/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.302486, train error 89.65,  test loss 2.302677, test error 89.88
# Epoch   100, train loss 2.302364, train error 89.65,  test loss 2.302986, test error 89.88
# Epoch   200, train loss 2.302356, train error 89.65,  test loss 2.302966, test error 89.88
# Epoch   300, train loss 2.302357, train error 89.65,  test loss 2.303011, test error 89.88
# Epoch   400, train loss 2.302357, train error 89.65,  test loss 2.302992, test error 89.88
# Epoch   500, train loss 2.302353, train error 89.65,  test loss 2.302985, test error 89.88
# Epoch   600, train loss 2.302355, train error 89.65,  test loss 2.302914, test error 89.88
# Epoch   700, train loss 2.302352, train error 89.65,  test loss 2.302959, test error 89.88
# Epoch   800, train loss 2.302356, train error 89.65,  test loss 2.302948, test error 89.88
# Epoch   900, train loss 2.302360, train error 89.65,  test loss 2.303042, test error 89.88
# Training model with   4 hidden variables
# Epoch     0, train loss 2.283416, train error 88.15,  test loss 2.274913, test error 88.78
# Epoch   100, train loss 1.724697, train error 62.58,  test loss 1.521632, test error 59.03
# Epoch   200, train loss 1.707615, train error 61.60,  test loss 1.519344, test error 58.12
# Epoch   300, train loss 1.706297, train error 62.42,  test loss 1.503847, test error 58.47
# Epoch   400, train loss 1.703301, train error 61.83,  test loss 1.518648, test error 57.78
# Epoch   500, train loss 1.703882, train error 61.20,  test loss 1.517474, test error 58.33
# Epoch   600, train loss 1.698967, train error 61.58,  test loss 1.511620, test error 58.20
# Epoch   700, train loss 1.697175, train error 61.85,  test loss 1.508674, test error 58.67
# Epoch   800, train loss 1.696208, train error 61.15,  test loss 1.510834, test error 58.25
# Epoch   900, train loss 1.695040, train error 61.35,  test loss 1.505924, test error 58.17
# Training model with   6 hidden variables
# Epoch     0, train loss 2.227292, train error 84.30,  test loss 2.209147, test error 83.93
# Epoch   100, train loss 1.629235, train error 57.03,  test loss 1.455961, test error 55.00
# Epoch   200, train loss 1.611977, train error 56.88,  test loss 1.440594, test error 54.92
# Epoch   300, train loss 1.597308, train error 56.33,  test loss 1.438240, test error 55.33
# Epoch   400, train loss 1.591311, train error 56.22,  test loss 1.439266, test error 55.00
# Epoch   500, train loss 1.594082, train error 56.35,  test loss 1.446878, test error 54.95
# Epoch   600, train loss 1.590325, train error 56.42,  test loss 1.444513, test error 55.88
# Epoch   700, train loss 1.589163, train error 56.42,  test loss 1.443959, test error 55.50
# Epoch   800, train loss 1.583590, train error 56.00,  test loss 1.442567, test error 54.38
# Epoch   900, train loss 1.579244, train error 55.88,  test loss 1.433781, test error 54.28
# Training model with   8 hidden variables
# Epoch     0, train loss 2.241674, train error 84.30,  test loss 2.228182, test error 83.20
# Epoch   100, train loss 1.645458, train error 57.88,  test loss 1.494845, test error 57.33
# Epoch   200, train loss 1.613580, train error 56.83,  test loss 1.486598, test error 57.53
# Epoch   300, train loss 1.592793, train error 56.90,  test loss 1.487096, test error 57.50
# Epoch   400, train loss 1.583413, train error 56.55,  test loss 1.492775, test error 57.33
# Epoch   500, train loss 1.579419, train error 56.00,  test loss 1.494473, test error 57.28
# Epoch   600, train loss 1.578597, train error 56.22,  test loss 1.498815, test error 56.47
# Epoch   700, train loss 1.572055, train error 56.47,  test loss 1.493989, test error 56.58
# Epoch   800, train loss 1.567923, train error 56.35,  test loss 1.500388, test error 57.40
# Epoch   900, train loss 1.568169, train error 57.05,  test loss 1.496978, test error 57.38
# Training model with  10 hidden variables
# Epoch     0, train loss 2.174411, train error 81.57,  test loss 2.117041, test error 79.93
# Epoch   100, train loss 1.605228, train error 56.90,  test loss 1.525889, test error 57.75
# Epoch   200, train loss 1.517519, train error 52.38,  test loss 1.456437, test error 54.05
# Epoch   300, train loss 1.488696, train error 51.85,  test loss 1.443453, test error 53.75
# Epoch   400, train loss 1.478604, train error 51.05,  test loss 1.429889, test error 52.85
# Epoch   500, train loss 1.465717, train error 50.67,  test loss 1.424795, test error 52.45
# Epoch   600, train loss 1.462827, train error 50.50,  test loss 1.433024, test error 53.33
# Epoch   700, train loss 1.454325, train error 50.33,  test loss 1.414224, test error 52.62
# Epoch   800, train loss 1.454744, train error 50.80,  test loss 1.434806, test error 53.75
# Epoch   900, train loss 1.446160, train error 50.28,  test loss 1.426900, test error 52.85
# Training model with  14 hidden variables
# Epoch     0, train loss 2.225924, train error 81.35,  test loss 2.213049, test error 81.50
# Epoch   100, train loss 1.493893, train error 52.28,  test loss 1.414387, test error 54.10
# Epoch   200, train loss 1.404573, train error 49.47,  test loss 1.386982, test error 51.62
# Epoch   300, train loss 1.341073, train error 46.33,  test loss 1.332345, test error 48.95
# Epoch   400, train loss 1.303429, train error 44.67,  test loss 1.325167, test error 47.90
# Epoch   500, train loss 1.295944, train error 44.17,  test loss 1.334949, test error 48.55
# Epoch   600, train loss 1.267804, train error 42.92,  test loss 1.318619, test error 47.72
# Epoch   700, train loss 1.254997, train error 43.28,  test loss 1.325289, test error 47.83
# Epoch   800, train loss 1.244483, train error 43.17,  test loss 1.339104, test error 47.50
# Epoch   900, train loss 1.242124, train error 42.55,  test loss 1.346365, test error 48.12
# Training model with  18 hidden variables
# Epoch     0, train loss 2.112642, train error 78.55,  test loss 2.085388, test error 78.28
# Epoch   100, train loss 1.313115, train error 44.35,  test loss 1.305700, test error 48.78
# Epoch   200, train loss 1.238290, train error 42.58,  test loss 1.332081, test error 48.42
# Epoch   300, train loss 1.190673, train error 40.40,  test loss 1.367844, test error 48.67
# Epoch   400, train loss 1.173732, train error 40.42,  test loss 1.409461, test error 50.22
# Epoch   500, train loss 1.154724, train error 39.83,  test loss 1.434136, test error 50.03
# Epoch   600, train loss 1.139881, train error 39.00,  test loss 1.480035, test error 50.58
# Epoch   700, train loss 1.128880, train error 39.05,  test loss 1.510347, test error 50.38
# Epoch   800, train loss 1.123015, train error 38.53,  test loss 1.520597, test error 50.25
# Epoch   900, train loss 1.114271, train error 38.67,  test loss 1.544130, test error 50.42
# Training model with  22 hidden variables
# Epoch     0, train loss 2.183240, train error 80.20,  test loss 2.156923, test error 79.25
# Epoch   100, train loss 1.220231, train error 39.67,  test loss 1.269085, test error 46.53
# Epoch   200, train loss 1.126473, train error 37.38,  test loss 1.343626, test error 48.30
# Epoch   300, train loss 1.077595, train error 36.40,  test loss 1.442284, test error 49.05
# Epoch   400, train loss 1.029760, train error 34.25,  test loss 1.504099, test error 49.72
# Epoch   500, train loss 1.017996, train error 34.38,  test loss 1.536196, test error 48.80
# Epoch   600, train loss 0.991723, train error 33.15,  test loss 1.602065, test error 49.75
# Epoch   700, train loss 0.973617, train error 32.32,  test loss 1.662078, test error 50.47
# Epoch   800, train loss 0.982148, train error 32.95,  test loss 1.697679, test error 50.92
# Epoch   900, train loss 0.958089, train error 31.88,  test loss 1.750967, test error 51.20
# Training model with  26 hidden variables
# Epoch     0, train loss 2.196046, train error 80.47,  test loss 2.187675, test error 80.03
# Epoch   100, train loss 1.244268, train error 41.35,  test loss 1.343592, test error 50.40
# Epoch   200, train loss 1.065589, train error 35.78,  test loss 1.441477, test error 50.67
# Epoch   300, train loss 1.009475, train error 35.50,  test loss 1.598126, test error 52.65
# Epoch   400, train loss 0.933398, train error 31.68,  test loss 1.666705, test error 52.45
# Epoch   500, train loss 0.905203, train error 31.05,  test loss 1.770830, test error 52.22
# Epoch   600, train loss 0.893346, train error 29.70,  test loss 1.867361, test error 53.42
# Epoch   700, train loss 0.873222, train error 29.32,  test loss 1.971927, test error 54.42
# Epoch   800, train loss 0.860304, train error 29.10,  test loss 2.067467, test error 55.42
# Epoch   900, train loss 0.861721, train error 29.62,  test loss 2.151569, test error 55.05
# Training model with  30 hidden variables
# Epoch     0, train loss 2.178800, train error 79.40,  test loss 2.133226, test error 77.70
# Epoch   100, train loss 1.131546, train error 37.88,  test loss 1.386245, test error 49.67
# Epoch   200, train loss 0.959018, train error 31.85,  test loss 1.541541, test error 51.50
# Epoch   300, train loss 0.897321, train error 30.07,  test loss 1.696927, test error 52.65
# Epoch   400, train loss 0.824154, train error 27.78,  test loss 1.832086, test error 52.72
# Epoch   500, train loss 0.796172, train error 26.95,  test loss 1.986623, test error 53.47
# Epoch   600, train loss 0.757766, train error 26.18,  test loss 2.152892, test error 54.58
# Epoch   700, train loss 0.741389, train error 25.45,  test loss 2.268806, test error 55.08
# Epoch   800, train loss 0.716789, train error 24.60,  test loss 2.399343, test error 54.78
# Epoch   900, train loss 0.685974, train error 23.32,  test loss 2.537615, test error 55.95
# Training model with  35 hidden variables
# Epoch     0, train loss 2.153511, train error 79.15,  test loss 2.127646, test error 78.50
# Epoch   100, train loss 1.024985, train error 33.70,  test loss 1.418042, test error 50.25
# Epoch   200, train loss 0.820326, train error 27.28,  test loss 1.731222, test error 51.70
# Epoch   300, train loss 0.698978, train error 23.53,  test loss 2.022014, test error 53.65
# Epoch   400, train loss 0.599660, train error 19.50,  test loss 2.370161, test error 55.55
# Epoch   500, train loss 0.547631, train error 17.62,  test loss 2.680219, test error 55.88
# Epoch   600, train loss 0.525505, train error 18.28,  test loss 3.054221, test error 55.60
# Epoch   700, train loss 0.468580, train error 15.62,  test loss 3.369418, test error 56.03
# Epoch   800, train loss 0.462951, train error 14.93,  test loss 3.686946, test error 56.42
# Epoch   900, train loss 0.456840, train error 15.97,  test loss 3.871141, test error 55.97
# Training model with  40 hidden variables
# Epoch     0, train loss 2.108708, train error 77.88,  test loss 2.050336, test error 76.88
# Epoch   100, train loss 0.897571, train error 28.93,  test loss 1.417691, test error 50.53
# Epoch   200, train loss 0.617392, train error 20.45,  test loss 1.928154, test error 52.60
# Epoch   300, train loss 0.505837, train error 17.45,  test loss 2.628024, test error 54.20
# Epoch   400, train loss 0.378629, train error 12.55,  test loss 3.333284, test error 56.00
# Epoch   500, train loss 0.315310, train error 10.85,  test loss 4.097268, test error 57.42
# Epoch   600, train loss 0.282441, train error 9.97,  test loss 4.862238, test error 57.97
# Epoch   700, train loss 0.300775, train error 10.45,  test loss 5.662255, test error 57.80
# Epoch   800, train loss 0.260331, train error 9.32,  test loss 6.323811, test error 57.42
# Epoch   900, train loss 0.264805, train error 9.70,  test loss 7.008018, test error 58.47
# Training model with  45 hidden variables
# Epoch     0, train loss 2.042763, train error 75.75,  test loss 1.965860, test error 74.65
# Epoch   100, train loss 0.839282, train error 27.60,  test loss 1.512934, test error 51.05
# Epoch   200, train loss 0.513842, train error 16.50,  test loss 2.160274, test error 52.55
# Epoch   300, train loss 0.361100, train error 12.18,  test loss 3.209953, test error 53.80
# Epoch   400, train loss 0.226821, train error 7.93,  test loss 4.305223, test error 54.28
# Epoch   500, train loss 0.161983, train error 5.07,  test loss 5.610989, test error 54.50
# Epoch   600, train loss 0.140319, train error 4.53,  test loss 6.718425, test error 54.65
# Epoch   700, train loss 0.017226, train error 0.00,  test loss 7.907747, test error 54.60
# Epoch   800, train loss 0.010679, train error 0.00,  test loss 8.687663, test error 55.05
# Epoch   900, train loss 0.007698, train error 0.00,  test loss 9.255921, test error 54.88
# Training model with  50 hidden variables
# Epoch     0, train loss 2.102551, train error 77.53,  test loss 2.071982, test error 77.03
# Epoch   100, train loss 0.741057, train error 23.18,  test loss 1.520730, test error 50.17
# Epoch   200, train loss 0.366709, train error 10.93,  test loss 2.450963, test error 52.83
# Epoch   300, train loss 0.154241, train error 3.75,  test loss 3.945188, test error 54.75
# Epoch   400, train loss 0.030276, train error 0.00,  test loss 5.489629, test error 55.35
# Epoch   500, train loss 0.013422, train error 0.00,  test loss 6.441895, test error 55.53
# Epoch   600, train loss 0.008375, train error 0.00,  test loss 7.052343, test error 55.72
# Epoch   700, train loss 0.005948, train error 0.00,  test loss 7.511700, test error 55.50
# Epoch   800, train loss 0.004576, train error 0.00,  test loss 7.871005, test error 55.35
# Epoch   900, train loss 0.003689, train error 0.00,  test loss 8.172567, test error 55.40
# Training model with  55 hidden variables
# Epoch     0, train loss 2.059283, train error 76.72,  test loss 2.003130, test error 75.60
# Epoch   100, train loss 0.632010, train error 19.18,  test loss 1.669099, test error 51.78
# Epoch   200, train loss 0.204754, train error 4.65,  test loss 3.133037, test error 54.88
# Epoch   300, train loss 0.037817, train error 0.03,  test loss 4.829916, test error 55.58
# Epoch   400, train loss 0.014864, train error 0.00,  test loss 5.861957, test error 55.70
# Epoch   500, train loss 0.008540, train error 0.00,  test loss 6.486150, test error 55.67
# Epoch   600, train loss 0.005890, train error 0.00,  test loss 6.935955, test error 55.83
# Epoch   700, train loss 0.004369, train error 0.00,  test loss 7.281241, test error 55.62
# Epoch   800, train loss 0.003449, train error 0.00,  test loss 7.571639, test error 55.70
# Epoch   900, train loss 0.002830, train error 0.00,  test loss 7.811444, test error 55.72
# Training model with  60 hidden variables
# Epoch     0, train loss 2.062988, train error 76.82,  test loss 2.002365, test error 75.95
# Epoch   100, train loss 0.532190, train error 16.05,  test loss 1.718742, test error 50.00
# Epoch   200, train loss 0.100904, train error 0.70,  test loss 3.346480, test error 52.78
# Epoch   300, train loss 0.019804, train error 0.00,  test loss 4.700598, test error 53.45
# Epoch   400, train loss 0.009461, train error 0.00,  test loss 5.403134, test error 53.78
# Epoch   500, train loss 0.005887, train error 0.00,  test loss 5.851924, test error 54.08
# Epoch   600, train loss 0.004202, train error 0.00,  test loss 6.187554, test error 54.20
# Epoch   700, train loss 0.003227, train error 0.00,  test loss 6.457203, test error 54.38
# Epoch   800, train loss 0.002603, train error 0.00,  test loss 6.676243, test error 54.47
# Epoch   900, train loss 0.002149, train error 0.00,  test loss 6.865025, test error 54.55
# Training model with  70 hidden variables
# Epoch     0, train loss 2.053978, train error 76.55,  test loss 2.001220, test error 77.28
# Epoch   100, train loss 0.365333, train error 9.47,  test loss 1.972667, test error 51.80
# Epoch   200, train loss 0.033732, train error 0.03,  test loss 3.609019, test error 52.70
# Epoch   300, train loss 0.010944, train error 0.00,  test loss 4.401708, test error 53.30
# Epoch   400, train loss 0.006175, train error 0.00,  test loss 4.854647, test error 53.60
# Epoch   500, train loss 0.004089, train error 0.00,  test loss 5.157974, test error 53.50
# Epoch   600, train loss 0.003035, train error 0.00,  test loss 5.399772, test error 53.62
# Epoch   700, train loss 0.002374, train error 0.00,  test loss 5.590928, test error 53.58
# Epoch   800, train loss 0.001940, train error 0.00,  test loss 5.751111, test error 53.58
# Epoch   900, train loss 0.001631, train error 0.00,  test loss 5.888748, test error 53.50
# Training model with  80 hidden variables
# Epoch     0, train loss 2.024168, train error 74.88,  test loss 1.983274, test error 75.35
# Epoch   100, train loss 0.221683, train error 3.50,  test loss 2.080591, test error 52.05
# Epoch   200, train loss 0.019180, train error 0.00,  test loss 3.298171, test error 52.67
# Epoch   300, train loss 0.007882, train error 0.00,  test loss 3.826880, test error 52.40
# Epoch   400, train loss 0.004693, train error 0.00,  test loss 4.134224, test error 52.58
# Epoch   500, train loss 0.003254, train error 0.00,  test loss 4.359909, test error 52.62
# Epoch   600, train loss 0.002449, train error 0.00,  test loss 4.535058, test error 52.65
# Epoch   700, train loss 0.001948, train error 0.00,  test loss 4.676718, test error 52.65
# Epoch   800, train loss 0.001606, train error 0.00,  test loss 4.798035, test error 52.67
# Epoch   900, train loss 0.001359, train error 0.00,  test loss 4.900223, test error 52.75
# Training model with  90 hidden variables
# Epoch     0, train loss 1.982935, train error 73.93,  test loss 1.917495, test error 73.38
# Epoch   100, train loss 0.163572, train error 1.80,  test loss 2.264043, test error 52.28
# Epoch   200, train loss 0.015983, train error 0.00,  test loss 3.411659, test error 52.08
# Epoch   300, train loss 0.006793, train error 0.00,  test loss 3.882118, test error 52.50
# Epoch   400, train loss 0.004127, train error 0.00,  test loss 4.165630, test error 52.33
# Epoch   500, train loss 0.002881, train error 0.00,  test loss 4.373432, test error 52.35
# Epoch   600, train loss 0.002185, train error 0.00,  test loss 4.533209, test error 52.40
# Epoch   700, train loss 0.001743, train error 0.00,  test loss 4.664027, test error 52.35
# Epoch   800, train loss 0.001440, train error 0.00,  test loss 4.774348, test error 52.40
# Epoch   900, train loss 0.001221, train error 0.00,  test loss 4.869752, test error 52.42
# Training model with 100 hidden variables
# Epoch     0, train loss 1.989194, train error 73.47,  test loss 1.909167, test error 73.47
# Epoch   100, train loss 0.091810, train error 0.15,  test loss 2.243686, test error 50.33
# Epoch   200, train loss 0.012189, train error 0.00,  test loss 3.083566, test error 50.25
# Epoch   300, train loss 0.005708, train error 0.00,  test loss 3.443176, test error 50.50
# Epoch   400, train loss 0.003559, train error 0.00,  test loss 3.666528, test error 50.62
# Epoch   500, train loss 0.002530, train error 0.00,  test loss 3.832257, test error 50.60
# Epoch   600, train loss 0.001939, train error 0.00,  test loss 3.961257, test error 50.60
# Epoch   700, train loss 0.001558, train error 0.00,  test loss 4.067602, test error 50.53
# Epoch   800, train loss 0.001294, train error 0.00,  test loss 4.157127, test error 50.58
# Epoch   900, train loss 0.001102, train error 0.00,  test loss 4.235346, test error 50.67
# Training model with 120 hidden variables
# Epoch     0, train loss 1.955629, train error 73.25,  test loss 1.901385, test error 73.20
# Epoch   100, train loss 0.051778, train error 0.00,  test loss 2.174526, test error 49.72
# Epoch   200, train loss 0.009582, train error 0.00,  test loss 2.771921, test error 49.47
# Epoch   300, train loss 0.004748, train error 0.00,  test loss 3.057430, test error 49.95
# Epoch   400, train loss 0.003028, train error 0.00,  test loss 3.234076, test error 49.90
# Epoch   500, train loss 0.002182, train error 0.00,  test loss 3.364844, test error 49.92
# Epoch   600, train loss 0.001685, train error 0.00,  test loss 3.470513, test error 50.10
# Epoch   700, train loss 0.001362, train error 0.00,  test loss 3.555833, test error 50.05
# Epoch   800, train loss 0.001136, train error 0.00,  test loss 3.629446, test error 50.03
# Epoch   900, train loss 0.000971, train error 0.00,  test loss 3.692565, test error 50.05
# Training model with 140 hidden variables
# Epoch     0, train loss 1.961699, train error 72.95,  test loss 1.896398, test error 73.25
# Epoch   100, train loss 0.036641, train error 0.00,  test loss 2.092627, test error 49.20
# Epoch   200, train loss 0.008051, train error 0.00,  test loss 2.544172, test error 49.10
# Epoch   300, train loss 0.004145, train error 0.00,  test loss 2.765604, test error 49.05
# Epoch   400, train loss 0.002690, train error 0.00,  test loss 2.906835, test error 49.15
# Epoch   500, train loss 0.001958, train error 0.00,  test loss 3.016860, test error 49.22
# Epoch   600, train loss 0.001521, train error 0.00,  test loss 3.101450, test error 49.40
# Epoch   700, train loss 0.001235, train error 0.00,  test loss 3.171924, test error 49.42
# Epoch   800, train loss 0.001034, train error 0.00,  test loss 3.232405, test error 49.35
# Epoch   900, train loss 0.000886, train error 0.00,  test loss 3.284475, test error 49.33
# Training model with 160 hidden variables
# Epoch     0, train loss 1.938452, train error 71.32,  test loss 1.854505, test error 71.78
# Epoch   100, train loss 0.028102, train error 0.00,  test loss 2.151310, test error 49.35
# Epoch   200, train loss 0.006978, train error 0.00,  test loss 2.564929, test error 49.53
# Epoch   300, train loss 0.003695, train error 0.00,  test loss 2.768045, test error 49.67
# Epoch   400, train loss 0.002432, train error 0.00,  test loss 2.903447, test error 49.70
# Epoch   500, train loss 0.001784, train error 0.00,  test loss 3.003331, test error 49.65
# Epoch   600, train loss 0.001394, train error 0.00,  test loss 3.083063, test error 49.67
# Epoch   700, train loss 0.001137, train error 0.00,  test loss 3.149230, test error 49.65
# Epoch   800, train loss 0.000954, train error 0.00,  test loss 3.206637, test error 49.62
# Epoch   900, train loss 0.000819, train error 0.00,  test loss 3.256191, test error 49.62
# Training model with 180 hidden variables
# Epoch     0, train loss 1.928239, train error 70.32,  test loss 1.867262, test error 71.97
# Epoch   100, train loss 0.025418, train error 0.00,  test loss 2.113504, test error 49.58
# Epoch   200, train loss 0.006777, train error 0.00,  test loss 2.486307, test error 49.47
# Epoch   300, train loss 0.003598, train error 0.00,  test loss 2.669334, test error 49.35
# Epoch   400, train loss 0.002380, train error 0.00,  test loss 2.792072, test error 49.22
# Epoch   500, train loss 0.001746, train error 0.00,  test loss 2.885877, test error 49.15
# Epoch   600, train loss 0.001366, train error 0.00,  test loss 2.960204, test error 49.20
# Epoch   700, train loss 0.001115, train error 0.00,  test loss 3.021621, test error 49.08
# Epoch   800, train loss 0.000937, train error 0.00,  test loss 3.074387, test error 49.15
# Epoch   900, train loss 0.000805, train error 0.00,  test loss 3.120914, test error 49.10
# Training model with 200 hidden variables
# Epoch     0, train loss 1.919679, train error 70.95,  test loss 1.857892, test error 73.12
# Epoch   100, train loss 0.022070, train error 0.00,  test loss 2.023173, test error 47.95
# Epoch   200, train loss 0.006257, train error 0.00,  test loss 2.336370, test error 47.62
# Epoch   300, train loss 0.003385, train error 0.00,  test loss 2.495852, test error 47.60
# Epoch   400, train loss 0.002254, train error 0.00,  test loss 2.603703, test error 47.50
# Epoch   500, train loss 0.001664, train error 0.00,  test loss 2.685252, test error 47.67
# Epoch   600, train loss 0.001307, train error 0.00,  test loss 2.751316, test error 47.70
# Epoch   700, train loss 0.001069, train error 0.00,  test loss 2.806127, test error 47.62
# Epoch   800, train loss 0.000900, train error 0.00,  test loss 2.853094, test error 47.65
# Epoch   900, train loss 0.000774, train error 0.00,  test loss 2.894398, test error 47.67
# Training model with 250 hidden variables
# Epoch     0, train loss 1.891438, train error 69.28,  test loss 1.832445, test error 70.72
# Epoch   100, train loss 0.016853, train error 0.00,  test loss 1.931833, test error 48.15
# Epoch   200, train loss 0.005251, train error 0.00,  test loss 2.199433, test error 48.38
# Epoch   300, train loss 0.002920, train error 0.00,  test loss 2.338083, test error 48.25
# Epoch   400, train loss 0.001969, train error 0.00,  test loss 2.433574, test error 48.17
# Epoch   500, train loss 0.001465, train error 0.00,  test loss 2.506200, test error 48.17
# Epoch   600, train loss 0.001156, train error 0.00,  test loss 2.564103, test error 48.38
# Epoch   700, train loss 0.000949, train error 0.00,  test loss 2.613074, test error 48.45
# Epoch   800, train loss 0.000802, train error 0.00,  test loss 2.654829, test error 48.53
# Epoch   900, train loss 0.000692, train error 0.00,  test loss 2.691782, test error 48.58
# Training model with 300 hidden variables
# Epoch     0, train loss 1.906389, train error 69.22,  test loss 1.824193, test error 70.47
# Epoch   100, train loss 0.014431, train error 0.00,  test loss 1.866682, test error 48.03
# Epoch   200, train loss 0.004817, train error 0.00,  test loss 2.081630, test error 47.55
# Epoch   300, train loss 0.002728, train error 0.00,  test loss 2.197976, test error 47.65
# Epoch   400, train loss 0.001859, train error 0.00,  test loss 2.278936, test error 47.47
# Epoch   500, train loss 0.001391, train error 0.00,  test loss 2.340933, test error 47.40
# Epoch   600, train loss 0.001102, train error 0.00,  test loss 2.391410, test error 47.33
# Epoch   700, train loss 0.000908, train error 0.00,  test loss 2.433373, test error 47.30
# Epoch   800, train loss 0.000769, train error 0.00,  test loss 2.469706, test error 47.22
# Epoch   900, train loss 0.000664, train error 0.00,  test loss 2.501583, test error 47.28
# Training model with 400 hidden variables
# Epoch     0, train loss 1.835502, train error 64.78,  test loss 1.777584, test error 68.85
# Epoch   100, train loss 0.011540, train error 0.00,  test loss 1.798159, test error 46.60
# Epoch   200, train loss 0.004137, train error 0.00,  test loss 1.978153, test error 45.97
# Epoch   300, train loss 0.002401, train error 0.00,  test loss 2.077536, test error 46.08
# Epoch   400, train loss 0.001655, train error 0.00,  test loss 2.148220, test error 46.10
# Epoch   500, train loss 0.001247, train error 0.00,  test loss 2.201575, test error 45.95
# Epoch   600, train loss 0.000994, train error 0.00,  test loss 2.245518, test error 45.90
# Epoch   700, train loss 0.000821, train error 0.00,  test loss 2.282419, test error 45.92
# Epoch   800, train loss 0.000697, train error 0.00,  test loss 2.313990, test error 45.97
# Epoch   900, train loss 0.000604, train error 0.00,  test loss 2.341615, test error 45.83

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
